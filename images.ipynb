# %% [markdown]
# ## Loading an Image

# %%
import skimage

# %%
# this is the first step in uploading an image to our notebook

# %%
from skimage import io

# %%
# this is the second step, it allows the image to be read

# %%
f = io.imread('cat.jpg')

# %%
# this allows us to read the image in our notebook

# %%
f.shape
# Out:
# (542, 880, 3)

# %%
# this gives the dimensions of the image

# %%
type(f)
# Out:
# numpy.ndarray

# %%
# this is the type of image

# %%
plt.imshow(f)

# %%
# this shows us our image!

# %%
from skimage.color import rgb2gray

# %%
# this would put our image in grayscale

# %%
grayscale = rgb2gray(f)

# %%
# this identifies the variable for our grayscale

# %%
plt.imshow(grayscale, cmap=plt.cm.gray)

# %%
# this shows us our image, now in grayscale. woohoo!

# %%
grayscale[4, 9]
# Out:
# 0.17647058823529416

# %%
rows = grayscale.shape[0]
cols = grayscale.shape[1]
def fairey (f):
    fairey = np.zeros((rows, cols, 3))
    
    for i in range (rows):
        for j in range (cols):
            if grayscale[i, j] > 0.75:
                fairey[i, j] = [0, 0, 255]
            elif grayscale[i, j] > 0.5:
                fairey[i, j] = [0, 255, 0]
            elif grayscale[i, j] > 0.3:
                fairey[i, j] = [20, 20, 20]
            else:
                fairey[i, j] = [255, 0, 0]
            return plt.imshow(fairey)

# %%
# this will put in our image in a new color scheme, using red, green, and blue

# %%
fairey
# Out:
# <function __main__.fairey(f)>

# %%
fairey('cat.jpg')
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# this was supposed to be in a new color scheme. oops! let's try again

# %%
a = io.imread('kitty.jpg')

# %%
a.shape
# Out:
# (183, 275, 3)

# %%
type(a)
# Out:
# numpy.ndarray

# %%
plt.imshow(a)

# %%
from skimage.color import rgb2gray

# %%
grayscale = rgb2gray(f)

# %%
plt.imshow(grayscale, cmap=plt.cm.gray)

# %%
grayscale[4, 9]
# Out:
# 0.370986274509804

# %%
def ok(image_file):
    a = io.imread(image_file)
grayscale = rgb2gray(a)
rows = grayscale.shape[0]
cols = grayscale.shape[1]
def ok (a):
    ok = np.zeros((rows, cols, 3))  
    for i in range (rows):
        for j in range (cols):
            if grayscale[i, j] > 0.75:
                ok[i, j] = [0, 0, 255] 
            elif grayscale[i, j] > 0.5:
                ok[i, j] = [0, 255, 0]
            elif grayscale[i, j] > 0.25:
                ok[i, j] = [255, 0, 0]
            else:
                ok[i, j] = [0, 0, 0]
            return plt.imshow(ok)

# %%
ok
# Out:
# <function __main__.ok(a)>

# %%
ok('kitty.jpg')

# %%
#oops!

# %% [markdown]
# ### Shephard Fairey
